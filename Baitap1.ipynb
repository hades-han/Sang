# %%
# shift + enter : run đoạn code, sau đó thêm 1 dòng mới

# %%
# ctrl + enter : chỉ run đoạn code

# %%
# cài đặt 
# !pip install Pillow
# !anaconda install Pillow

# %%
# Import thư viện
from PIL import Image

# %%
# Thư mục chứa ảnh 
# Trong python dùng dấu / \\
# Thư mục chứa ảnh
directory = 'C:/HinhAnhThiGiacMayTinh'

# %%
image_path =  directory + '/img04.png'
print(image_path)
# Out:
# C:/HinhAnhThiGiacMayTinh/img04.png

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=275x183>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  PNG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (275, 183)

# %%
# Convert the image to RGB mode if it has an alpha channel
if img01.mode == 'RGBA':
    img01 = img01.convert('RGB')

# Save the image in JPEG format
new_img_01_path = directory + '/new_01.JPG'
new_img_png_01_path = directory + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
# Đóng tập tin
img01.close()
